# %%
from nltk.corpus import wordnet as wn 
import pandas as pd
import os
import shutil
import random

# %%
# Get bird names from nltk corpus
bird1 = wn.synset('bird.n.01')
bird_list1 = list(set([w for s in bird1.closure(lambda s: s.hyponyms()) for w in s.lemma_names()]))

bird2 = wn.synset('bird.n.02')
bird_list2 = list(set([w for s in bird2.closure(lambda s: s.hyponyms()) for w in s.lemma_names()]))

len(bird_list1), len(bird_list2)
# Out:
# (1736, 27)

# %%
bird_list = list(set(bird_list1+bird_list2))
len(bird_list)
# Out:
# 1747

# %%
# Clean up bird_list data
bird_list = [bird.replace("_"," ") for bird in bird_list]
bird_list
# Out:
# ['Adelie',
#  'Cygnus olor',
#  'cardinal',
#  'Eudromias morinellus',
#  'yellow warbler',
#  'Maryland yellowthroat',
#  'goony',
#  'black-fronted bush shrike',
#  'black-necked stork',
#  'shrike',
#  'grebe',
#  'bantam',
#  'bellbird',
#  'throstle',
#  'apteryx',
#  'honeycreeper',
#  'Cistothorus palustris',
#  'tanager',
#  'Melanotis caerulescens',
#  'Tringa totanus',
#  'great grey owl',
#  'mourning dove',
#  'Delichon urbica',
#  'chunga',
#  'Spheniscus demersus',
#  'kaki',
#  'button-quail',
#  'hepatic tanager',
#  'common spoonbill',
#  'whydah',
#  'trogon',
#  'courlan',
#  'Emberiza hortulana',
#  'New World sparrow',
#  'Parus caeruleus',
#  'pyrrhuloxia',
#  'pea-chick',
#  'sulphur-crested cockatoo',
#  'white-crowned sparrow',
#  'golden eagle',
#  'scrubbird',
#  'antbird',
#  'moa',
#  'shoebill',
#  'wood swallow',
#  'jacamar',
#  'Oreortyx picta palmeri',
#  'Calidris canutus',
#  'Luscinia megarhynchos',
#  'Leptoptilus dubius',
#  'Cursorius cursor',
#  'crow blackbird',
#  'penguin',
#  'Bartramia longicauda',
#  'Auriparus flaviceps',
#  'Spinus pinus',
#  'marabout',
#  'Columba fasciata',
#  'night bird',
#  'passenger pigeon',
#  'Himantopus mexicanus',
#  'long-billed marsh wren',
#  'touraco',
#  'Chrysolophus pictus',
#  'European curlew',
#  'Mergus merganser',
#  'horned owl',
#  'Cyanocitta cristata',
#  'quetzal bird',
#  'Old World quail',
#  'sage hen',
#  'grey catbird',
#  'saddlebill',
#  'bobwhite',
#  'black turnstone',
#  'swallow shrike',
#  'wood stork',
#  'Sphyrapicus varius',
#  'lesser prairie chicken',
#  'turacou',
#  'tomtit',
#  'tree creeper',
#  'red-shafted flicker',
#  'ivory gull',
#  'Tympanuchus cupido',
#  'raptor',
#  'knot',
#  'myrtle warbler',
#  'indigo bunting',
#  'trumpeter',
#  'lesser scaup duck',
#  'hedge sparrow',
#  'myrtle bird',
#  'Cygnus atratus',
#  'Aythya americana',
#  'Alectoris ruffa',
#  'grass finch',
#  'woodpecker',
#  'snowflake',
#  'razor-billed auk',
#  'hobby',
#  'duck',
#  'Uria lomvia',
#  'crested myna',
#  'goldeneye',
#  'black-necked stilt',
#  'Vireo solitarius',
#  'Mergus serrator',
#  'barbet',
#  'short-billed marsh wren',
#  'Eskimo curlew',
#  'macaw',
#  'amazon',
#  'whistler',
#  'Gypaetus barbatus',
#  'rock pigeon',
#  'Philohela minor',
#  'wildfowl',
#  'Anhinga anhinga',
#  'cream-colored courser',
#  'scooter',
#  'meadowlark',
#  'thickhead',
#  'kingbird',
#  'greater whitethroat',
#  'dickybird',
#  'Australian magpie',
#  'cacique',
#  'Anas clypeata',
#  'Chauna torquata',
#  'adjutant',
#  'purple martin',
#  'Fulmarus glacialis',
#  'little owl',
#  'Haliaeetus leucocephalus',
#  'lammergeier',
#  'shorebird',
#  'grey hen',
#  'northern parula',
#  'wren warbler',
#  'Anser anser',
#  'paroquet',
#  'scrub fowl',
#  'Pagophila eburnea',
#  'pintail',
#  'spotted flycatcher',
#  'Casmerodius albus',
#  'Fulica americana',
#  'Coturnix communis',
#  'hooter',
#  'redtail',
#  'eaglet',
#  'bank swallow',
#  'glareole',
#  'Catharacta skua',
#  'piciform bird',
#  'honey eater',
#  'water thrush',
#  'Strix nebulosa',
#  'whisker jack',
#  'wren-tit',
#  'field sparrow',
#  'cockateel',
#  'woodhewer',
#  'greater yellowlegs',
#  'pectoral sandpiper',
#  'Saxicola rubetra',
#  'water bird',
#  'ostrich',
#  'siskin',
#  'barred owl',
#  'peacock',
#  'poultry',
#  'guinea fowl',
#  'tawny eagle',
#  'Ploceus philippinus',
#  'Contopus virens',
#  'thrasher',
#  'rock wren',
#  'sand martin',
#  'European creeper',
#  'heath hen',
#  'Alauda arvensis',
#  'European nightjar',
#  'Cairina moschata',
#  'Hirundo pyrrhonota',
#  'Polynesian tattler',
#  'Carpodacus mexicanus',
#  'Aptenodytes patagonica',
#  'fishing eagle',
#  'bittern',
#  'eider',
#  'buteonine',
#  'Xenorhyncus asiaticus',
#  'woodcock snipe',
#  'honeysucker',
#  'ruddy duck',
#  'Old World oriole',
#  'canvasback',
#  'Erolia alpina',
#  'dickeybird',
#  'tree martin',
#  'Coccothraustes coccothraustes',
#  'scarlet tanager',
#  'black cock',
#  'Anas querquedula',
#  'Nymphicus hollandicus',
#  'Buteo buteo',
#  'Alca torda',
#  'Chen caerulescens',
#  'white-tailed sea eagle',
#  'Pyrocephalus rubinus mexicanus',
#  'white-throated sparrow',
#  'black-winged stilt',
#  'gosling',
#  'barn owl',
#  'quack-quack',
#  'banded stilt',
#  'Catoptrophorus semipalmatus',
#  'titmouse',
#  'finch',
#  'killdeer plover',
#  'Pavo cristatus',
#  'raptorial bird',
#  'Ptloris paradisea',
#  'Cape May warbler',
#  'yellowbird',
#  'Old World scops owl',
#  'crane',
#  'godwit',
#  'lesser whitethroat',
#  'honey buzzard',
#  'Corvus frugilegus',
#  'loon',
#  'bullfinch',
#  'Manx shearwater',
#  'jacksnipe',
#  'Progne subis',
#  'Puffinus puffinus',
#  'wood drake',
#  'Egyptian vulture',
#  'pitta',
#  'Coragyps atratus',
#  'grey jay',
#  'cedarbird',
#  'archaeopteryx',
#  'eastern meadowlark',
#  'red-breasted merganser',
#  'Nycticorax nycticorax',
#  'common scoter',
#  'peckerwood',
#  'petrel',
#  'Platalea leucorodia',
#  'Meleagris gallopavo',
#  'tiercel',
#  'belted kingfisher',
#  'ani',
#  'cackler',
#  'pine finch',
#  'Cuculus canorus',
#  'Garullus garullus',
#  'murre',
#  'Turdus philomelos',
#  'Oriolus oriolus',
#  'condor',
#  'nuthatch',
#  'Lofortyx californicus',
#  'golden-crested kinglet',
#  'bird of passage',
#  'Rhea americana',
#  'frogmouth',
#  'snowbird',
#  'grackle',
#  'adjutant bird',
#  'Streptopelia risoria',
#  'frigate bird',
#  'indigo bird',
#  'Old World chat',
#  'Cardinalis cardinalis',
#  'turnstone',
#  'Euopean hoopoe',
#  'sea swallow',
#  "Cassin's kingbird",
#  'bobwhite quail',
#  'Tympanuchus cupido cupido',
#  'Ceryle alcyon',
#  'mina',
#  'Tyrannus domenicensis domenicensis',
#  'rhea',
#  'yellow bunting',
#  'Archaeopteryx lithographica',
#  'Pterocles indicus',
#  'hooded sheldrake',
#  'Leptoptilus crumeniferus',
#  'Muscivora-forficata',
#  'Anas rubripes',
#  'grey kingbird',
#  'toucan',
#  'goldcrest',
#  'skimmer',
#  'Hungarian partridge',
#  'mew gull',
#  'reed bunting',
#  'Egretta garzetta',
#  'baldpate',
#  'crocodile bird',
#  'grey partridge',
#  'American eagle',
#  'Coturnix coturnix',
#  'Cochlearius cochlearius',
#  'western tanager',
#  'fowl',
#  'twitterer',
#  'ground roller',
#  'Hylocichla guttata',
#  'Stictopelia cuneata',
#  'parrot',
#  'migrant shrike',
#  'sparrow',
#  'cochin china',
#  'roseate spoonbill',
#  'wood hoopoe',
#  'gander',
#  'dipper',
#  'true flycatcher',
#  'ant shrike',
#  'brent goose',
#  'Canadian goose',
#  'kingfisher',
#  'Luscinia luscinia',
#  'stilt',
#  'Limnocryptes minima',
#  'Dendroica petechia',
#  'clay-colored robin',
#  'cockatoo',
#  'widow bird',
#  'painted sandgrouse',
#  'Ortilis vetula macalli',
#  'eyas',
#  'Fringilla montifringilla',
#  'canary',
#  'red-breasted snipe',
#  'Colaptes caper collaris',
#  'horned puffin',
#  'wood thrush',
#  'Phalacrocorax carbo',
#  'orchard oriole',
#  "Wilson's thrush",
#  'capercailzie',
#  'jungle cock',
#  'tufted puffin',
#  'falcon-gentil',
#  'European roller',
#  'Aythya ferina',
#  'Bohemian waxwing',
#  'Sinornis',
#  'Pinguinus impennis',
#  'wood duck',
#  'bonxie',
#  'Blackburn',
#  'bluethroat',
#  'titlark',
#  'gray jay',
#  'bee eater',
#  'tree swallow',
#  'oceanic bird',
#  'Tyrannus tyrannus',
#  'Colaptes auratus',
#  'mocking thrush',
#  'Charadrius vociferus',
#  'Alcedo atthis',
#  'Otus scops',
#  'Serinus canaria',
#  'Parus bicolor',
#  'camp robber',
#  'grouse',
#  'serin',
#  'Caprimulgus vociferus',
#  'Prunella modularis',
#  "Mother Carey's hen",
#  'Dacelo gigas',
#  'carrier pigeon',
#  'phalarope',
#  'pin-tailed grouse',
#  'Diomedea nigripes',
#  'gooney bird',
#  'gilded flicker',
#  'Buteo jamaicensis',
#  'Himantopus himantopus leucocephalus',
#  'Crocethia alba',
#  'marsh hen',
#  'myna bird',
#  'wood pewee',
#  'bush tit',
#  'American merganser',
#  'peregrine',
#  'varied Lorikeet',
#  'Psittacus erithacus',
#  'budgie',
#  'lesser scaup',
#  'house wren',
#  'Aix sponsa',
#  'guinea hen',
#  'Hirundo nigricans',
#  'oriole',
#  'Cephalopterus ornatus',
#  'pipit',
#  'poorwill',
#  'Philomachus pugnax',
#  'scissortailed flycatcher',
#  'Porphyrula martinica',
#  'gamecock',
#  'aepyornis',
#  'gray hen',
#  'white-tailed kite',
#  'Regulus satrata',
#  'half snipe',
#  'Icterus galbula bullockii',
#  'jungle hen',
#  'blue tit',
#  'carinate',
#  'chat',
#  'dotrel',
#  'Asio otus',
#  'Turdus migratorius',
#  'bufflehead',
#  'green peafowl',
#  'Blackburnian warbler',
#  'crested penguin',
#  'Carduelis cucullata',
#  'dickey-bird',
#  'budgereegah',
#  'Falco rusticolus',
#  'Emu novaehollandiae',
#  'Threskiornis aethiopica',
#  'Haliaeetus pelagicus',
#  'merle',
#  'red-necked grebe',
#  'heron',
#  'lowan',
#  'tragopan',
#  'scissortail',
#  'falcon-gentle',
#  'mud hen',
#  'boatbill',
#  'jenny wren',
#  'Bubulcus ibis',
#  'Padda oryzivora',
#  'Burhinus oedicnemus',
#  'tyrant flycatcher',
#  'gallinule',
#  'magpie',
#  'garganey',
#  'crake',
#  'Nucifraga caryocatactes',
#  'mockingbird',
#  'whooper swan',
#  'pheasant cuckoo',
#  'whole snipe',
#  'greyhen',
#  'golden pheasant',
#  'waterfowl',
#  'great snipe',
#  'ptarmigan',
#  'Procellaria aequinoctialis',
#  'brant',
#  'Fringilla coelebs',
#  'Sturnella neglecta',
#  'Hirundo rustica',
#  'Picus viridis',
#  'cockatiel',
#  'sea bird',
#  'Opisthocomus hoazin',
#  'greylag',
#  'Greek partridge',
#  'Jabiru mycteria',
#  'stone curlew',
#  'lovebird',
#  'Limosa haemastica',
#  'mocker',
#  'Upupa epops',
#  "Audubon's warbler",
#  'poll',
#  'harpy',
#  'coraciiform bird',
#  'pewit gull',
#  'Balaeniceps rex',
#  'Oven Stuffer',
#  'house martin',
#  'black swan',
#  'Branta leucopsis',
#  'little egret',
#  'Lunda cirrhata',
#  'Kakatoe leadbeateri',
#  'Leipoa ocellata',
#  'ortolan bunting',
#  'herring gull',
#  'harrier',
#  'red-backed sandpiper',
#  'blue-headed vireo',
#  'pine siskin',
#  'baya',
#  'Bartramian sandpiper',
#  'greater prairie chicken',
#  'puffbird',
#  'dabbling duck',
#  'Piranga flava hepatica',
#  'fieldfare',
#  'pied-billed grebe',
#  'umbrella bird',
#  'Podiceps cristatus',
#  'songster',
#  'turkey cock',
#  'Fratercula arctica',
#  'Passer montanus',
#  'game fowl',
#  'greenwing',
#  'Fulica atra',
#  'Thryothorus ludovicianus',
#  'teal',
#  'Larus canus',
#  'grayback',
#  'Nucifraga columbiana',
#  'European nuthatch',
#  'tropic bird',
#  'parroquet',
#  'Pandion haliaetus',
#  'Rupicola peruviana',
#  'Accipitriformes',
#  'Turdus torquatus',
#  'gooney',
#  'gannet',
#  'Actitis hypoleucos',
#  'European cuckoo',
#  'sedge wren',
#  'mosquito hawk',
#  'chimney swallow',
#  'curassow',
#  'Himantopus himantopus',
#  'chicken hawk',
#  'mountain quail',
#  'Melospiza georgiana',
#  'Contopus sordidulus',
#  'Parula americana',
#  'flamingo',
#  'green plover',
#  'great bowerbird',
#  'Carolina parakeet',
#  'sea duck',
#  'Bombycilla garrulus',
#  'anseriform bird',
#  'red-breasted sapsucker',
#  'shell parakeet',
#  'Colaptes chrysoides',
#  'rooster',
#  'Loxia curvirostra',
#  'Carduelis carduelis',
#  'redstart',
#  'maori hen',
#  'northern phalarope',
#  'band-tail pigeon',
#  'Pica pica',
#  'bell magpie',
#  'wood hen',
#  'Otis tarda',
#  'European black grouse',
#  'grossbeak',
#  'harpy eagle',
#  'spotted owl',
#  'oystercatcher',
#  'gray kingbird',
#  'skylark',
#  'kookaburra',
#  'moorcock',
#  'Sitta canadensis',
#  'Aythya marila',
#  'Tetrao urogallus',
#  'Lagopus scoticus',
#  'parroket',
#  'Cornish fowl',
#  'willet',
#  'flycatcher',
#  'American oriole',
#  'black-footed albatross',
#  'Psittacula krameri',
#  'shoveller',
#  'spatchcock',
#  'crossbill',
#  'Dendroica fusca',
#  'Passerina cyanea',
#  'avadavat',
#  'squab',
#  'falcon',
#  'catbird',
#  'Audubon warbler',
#  'ring thrush',
#  'broadbill',
#  'caprimulgiform bird',
#  'Dendroica auduboni',
#  'graylag',
#  'Aix galericulata',
#  'Zonotrichia albicollis',
#  'cockerel',
#  'mute swan',
#  'kinglet',
#  'Ardea occidentalis',
#  'Melopsittacus undulatus',
#  'fish eagle',
#  'marabou stork',
#  'lyrebird',
#  'mound bird',
#  'greenshank',
#  'bank martin',
#  'black-backed gull',
#  'Pelecanus onocrotalus',
#  'gobbler',
#  'Colinus virginianus',
#  'song thrush',
#  'Pinicola enucleator',
#  'dovekie',
#  'chaparral cock',
#  'killdeer',
#  'Turdus viscivorus',
#  'Haliatus albicilla',
#  'yellow-breasted bunting',
#  'tom turkey',
#  'American egret',
#  'Eurasian kingfisher',
#  'Gyps fulvus',
#  'Java sparrow',
#  'pouter pigeon',
#  'afropavo',
#  'vermillion flycatcher',
#  'creeper',
#  'gnatcatcher',
#  'brood hen',
#  'northern oriole',
#  'Acanthisitta chloris',
#  'Pedionomus torquatus',
#  'sandpiper',
#  "pallas's sandgrouse",
#  'missel thrush',
#  'Chunga burmeisteri',
#  'Corvus corax',
#  'whinchat',
#  'whidah',
#  'Centrocercus urophasianus',
#  'mistle thrush',
#  'brown thrush',
#  'Centropus phasianinus',
#  'Mergus merganser americanus',
#  'bustard quail',
#  'grayhen',
#  'Alectura lathami',
#  'brent',
#  'northern shrike',
#  'Pluvianus aegyptius',
#  'striped button quail',
#  'ortygan',
#  'rusty grackle',
#  'African grey',
#  'Tyto alba',
#  'turkey',
#  'diver',
#  'honker',
#  'lorikeet',
#  'piping crow',
#  'Gallinago gallinago',
#  'hoatzin',
#  'Limnodromus scolopaceus',
#  'pewit',
#  'apodiform bird',
#  'bluebill',
#  'Pipilo erythrophthalmus',
#  'Otus asio',
#  'Piranga olivacea',
#  'pouter',
#  'Steganopus tricolor',
#  'upland sandpiper',
#  'European goatsucker',
#  'woodcreeper',
#  'tufted titmouse',
#  'plain turkey',
#  'peewee',
#  'woodcock',
#  'gerfalcon',
#  'booby',
#  'dunnock',
#  'hornbill',
#  'Gracula religiosa',
#  'thick-billed murre',
#  'Columba palumbus',
#  'chipping sparrow',
#  'red-shouldered hawk',
#  'Accipiter gentilis',
#  'trumpeter swan',
#  'lintwhite',
#  'hill myna',
#  'tattler',
#  'green-tailed towhee',
#  'Charadrius melodus',
#  'swallow-tailed kite',
#  'tercel',
#  'redbreast',
#  'Tringa melanoleuca',
#  'redpoll',
#  'homing pigeon',
#  'Mimus polyglotktos',
#  'procellariiform seabird',
#  'Ciconia nigra',
#  'Sayornis phoebe',
#  'songbird',
#  'sea eagle',
#  'New World flycatcher',
#  'mavis',
#  'Polyborus plancus',
#  'canvasback duck',
#  'American robin',
#  'jaybird',
#  'Parus atricapillus',
#  'game bird',
#  'Aegypiidae',
#  'long-legs',
#  'harrier eagle',
#  'little grebe',
#  'pelican',
#  'policeman bird',
#  'guan',
#  'Phalaropus fulicarius',
#  'Calidris Ferruginea',
#  'Erolia minutilla',
#  'Congo peafowl',
#  'curlew',
#  'crested cariama',
#  'kildeer',
#  'Strix occidentalis',
#  'Columba livia',
#  'Chlorophoneus nigrifrons',
#  'phoebe bird',
#  'Circus Aeruginosus',
#  'European blackbird',
#  'butcherbird',
#  'Dromaius novaehollandiae',
#  'pigeon hawk',
#  'aquatic bird',
#  'California quail',
#  'cockatoo parrot',
#  'goatsucker',
#  'limicoline bird',
#  'purple grackle',
#  'cochin',
#  'tichodrome',
#  'Athene noctua',
#  'white-chinned petrel',
#  'Actitis macularia',
#  'limpkin',
#  'green woodpecker',
#  'parula warbler',
#  'Accipiter nisus',
#  'Stercorarius parasiticus',
#  'bullbat',
#  'quail',
#  'Vultur gryphus',
#  'bird of Minerva',
#  'Streptopelia turtur',
#  'Egretta albus',
#  'Rock Cornish',
#  'martin',
#  'sanderling',
#  'evening grosbeak',
#  "Mother Carey's chicken",
#  'seriema',
#  'volaille',
#  'brant goose',
#  'chicken',
#  'sphenisciform seabird',
#  'nightjar',
#  'Cacatua galerita',
#  'spotted antbird',
#  'Spinus tristis',
#  'great bustard',
#  'upland plover',
#  'snowy heron',
#  'purple finch',
#  'Baltimore oriole',
#  'grass parakeet',
#  'Cistothorus platensis',
#  'Mergus albellus',
#  'flying bird',
#  'flightless bird',
#  'Alectoris graeca',
#  'Dominique',
#  'redbird',
#  'griffon',
#  'moor-bird',
#  'duckling',
#  'Sceloglaux albifacies',
#  'mound builder',
#  'Melospiza melodia',
#  'Arenaria-Melanocephala',
#  'manakin',
#  'blue-winged teal',
#  'Hydrobates pelagicus',
#  'Tichodroma muriaria',
#  'solan',
#  'rough-legged hawk',
#  'carrion crow',
#  'Sturnella magna',
#  'Sylvia communis',
#  'cliff swallow',
#  'Gallinula chloropus',
#  'tinamou',
#  'Wilsonia pusilla',
#  'oyster catcher',
#  'fryer',
#  'Agriocharis ocellata',
#  'Falco columbarius',
#  'Piranga ludoviciana',
#  'Buteo lagopus',
#  'hawfinch',
#  'kittiwake',
#  'piping crow-shrike',
#  'Falco tinnunculus',
#  'blackpoll',
#  'veery',
#  'chough',
#  'petchary',
#  'broody hen',
#  'red-legged partridge',
#  'ruby-crowned wren',
#  'merl',
#  'bunting',
#  'Tyrannus vociferans',
#  'Collocalia inexpectata',
#  'Lanius lucovicianus',
#  'ortolan',
#  'fairy bluebird',
#  'egret',
#  'monaul',
#  'chachalaca',
#  'notornis',
#  'Heteroscelus incanus',
#  'black duck',
#  'Hylophylax naevioides',
#  'Orpington',
#  'flinthead',
#  'giant petrel',
#  'bandtail',
#  'cushat',
#  'toucanet',
#  'rainbow lorikeet',
#  'mound-bird',
#  'Lyrurus mlokosiewiczi',
#  'song sparrow',
#  'goldfinch',
#  'great white heron',
#  'Neophron percnopterus',
#  'Branta bernicla',
#  'swallow-tailed hawk',
#  'roller',
#  "Barrow's goldeneye",
#  'babbler',
#  'Canada goose',
#  'New World blackbird',
#  'phasianid',
#  'flicker',
#  'Carduelis hornemanni',
#  'gaviiform seabird',
#  'banana quit',
#  'dunlin',
#  'Gallinago gallinago delicata',
#  'pratincole',
#  'cuculiform bird',
#  'Raphus cucullatus',
#  'black grouse',
#  'Atlantic puffin',
#  'European bittern',
#  'shoveler',
#  'black stork',
#  'spotted sandpiper',
#  'ousel',
#  'blue goose',
#  'Ixobrychus exilis',
#  'piculet',
#  'American crow',
#  'kea',
#  'European sea eagle',
#  'yellowlegs',
#  'merganser',
#  'mountain partridge',
#  'Porzana porzana',
#  'cathartid',
#  'blue peafowl',
#  'fairy swallow',
#  'nandu',
#  'Cathartes aura',
#  'great crested grebe',
#  'Coracias garrulus',
#  'yellowhammer',
#  'stinkbird',
#  'king vulture',
#  'albatross',
#  'yellow-bellied sapsucker',
#  'ratite bird',
#  'warbler',
#  'Mycteria americana',
#  'goose',
#  'Toxostoma rufums',
#  'sea gull',
#  'accentor',
#  'ruddy turnstone',
#  'Choriotis australis',
#  'ringdove',
#  'house sparrow',
#  'Egretta caerulea',
#  'cock of the rock',
#  'vireo',
#  'bowerbird',
#  'Bucephala islandica',
#  'red jungle fowl',
#  'chimney swift',
#  'pen',
#  'Hawaiian honeycreeper',
#  'Charadrius morinellus',
#  'erne',
#  'auklet',
#  'wood widgeon',
#  'Lanius excubitor',
#  'anhinga',
#  'dabbler',
#  'prairie fowl',
#  'Icteria virens',
#  'avocet',
#  'Numenius borealis',
#  'frier',
#  'domestic fowl',
#  'sharp-tailed grouse',
#  'sapsucker',
#  'marsh harrier',
#  'Agelaius phoeniceus',
#  'pin-tailed sandgrouse',
#  'dove',
#  'Oriental scops owl',
#  'Sterna hirundo',
#  'starling',
#  'daw',
#  "Audubon's caracara",
#  'fulmar',
#  'loggerhead shrike',
#  'Emberiza citrinella',
#  'Botaurus stellaris',
#  'scoter',
#  'argus',
#  'Circus cyaneus',
#  'jabiru',
#  'pin-tailed duck',
#  'Muscicapa striata',
#  'northern bobwhite',
#  'gray catbird',
#  'poulet',
#  'wading bird',
#  'Ajaia ajaja',
#  'Melanitta nigra',
#  'Podilymbus podiceps',
#  'American widgeon',
#  'Aramus guarauna',
#  'swamphen',
#  'Turnix sylvatica',
#  'Sarcorhamphus papa',
#  'linnet',
#  'Rock Cornish hen',
#  "Pharaoh's chicken",
#  'shore bird',
#  'brambling',
#  'meadow pipit',
#  'smew',
#  'Ciconia ciconia',
#  "Wilson's phalarope",
#  'Sula bassana',
#  'ring-necked parakeet',
#  'New Zealand wren',
#  'longlegs',
#  'Troglodytes aedon',
#  'Gallus gallus',
#  'yellow-breasted chat',
#  'dowitcher',
#  'Clangula hyemalis',
#  'Anas americana',
#  'wood-creeper',
#  'red-breasted nuthatch',
#  'Aegypius monachus',
#  'least bittern',
#  'Strix varia',
#  'great skua',
#  'hen',
#  'cob',
#  'roadrunner',
#  'Pygoscelis adeliae',
#  'passeriform bird',
#  'Riparia riparia',
#  ...]

# %%
# Get generic bird name
generic_bird_name = []
for a in bird_list:
    generic_bird_name.append(a.split(" ")[-1])

generic_bird_name = list(set(generic_bird_name))
pattern = '|'.join(generic_bird_name)

# %%
# Get ImageNet class keys to download images from ImageNet
df = pd.read_csv("./ImageNet-Datasets-Downloader/classes_in_imagenet.csv")
df["class_name"] = df["class_name"].str.lower()
df.dropna(inplace=True)
df.head()
# Out:
#        synid   class_name  urls  flickr_urls
# 0  n00004475     organism     8            6
# 1  n00005787      benthos  1264          626
# 2  n00006024  heterotroph     1            0
# 3  n00006484         cell  1251          628
# 4  n00007846       person  1242         1138

# %%
df['class_name'].shape[0], df['class_name'].nunique()
# Out:
# (21839, 20067)

# %%
# Removing bird from imagenet dataset
df_non_bird = df[~df['class_name'].isin(bird_list)]
df_non_bird = df_non_bird[~df_non_bird['class_name'].str.contains(pattern)]

# %%
# Removing duplicates
df_non_bird = df_non_bird.drop_duplicates('class_name')

# %%
# Get non_bird id and name
# limit to only 7501 classes via random sampling
df_non_bird = df_non_bird.sample(n=7501,replace=False,random_state=42)
non_bird_id = df_non_bird['synid'].tolist()
non_bird_name = df_non_bird['class_name'].tolist()
non_bird_dict = dict(zip(non_bird_id, non_bird_name))

# %%
len(non_bird_dict)
# Out:
# 7501

# %%
# Creare function to turn list of strings into single long string (to be executed on command line)
def convert_list_to_long_string(target_list):
    long_string=""
    for item in target_list:
        long_string += " " + item
    long_string = long_string[1:]
    return long_string

non_bird_id_string = convert_list_to_long_string(non_bird_id)
non_bird_id_string[:53]
# Out:
# 'n10223606 n04390977 n03938401 n09936892 n01491874 n01'

# %%
# Download non_bird image from imagenet 
'''
# !python3 ImageNet-Datasets-Downloader/downloader.py \
-data_root dataset/non_bird_images \
-use_class_list True \
-class_list $non_bird_id_string\
-images_per_class 10
'''
# Out:
# '\n!python3 ImageNet-Datasets-Downloader/downloader.py -data_root dataset/non_bird_images -use_class_list True -class_list $non_bird_id_string-images_per_class 10\n'

# %%
# Download image with bing image downloader
from bing_image_downloader import downloader
for query in non_bird_name:
    downloader.download(query, limit=5,  output_dir='dataset/temp', force_replace=False, verbose=False)
# Out:
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp
auto=format&amp;fit=max&amp;h=800&amp;ixlib=php-2.1.1&amp;q=35&amp;s=279c6a1352f1ce9f9cbfb862b2a6d71b
# [!] Error:: HTTP Error 403: Forbidden
# [!] Issue getting: http://www.pinguicula.org/A_world_of_Pinguicula_2/images/postcard_22/P_gypsicola_&amp;_P_takakii_habitats_ravine_on_other_side_of_the_mountain(HR).jpg
# [!] Error:: HTTP Error 404: Not Found
# [!] Issue getting: https://wolfgangglowacki.com.au/sites/wolfgangglowacki.com.au/files/print_images/CV011 The Great Ravine.jpg
# [!] Error:: URL can't contain control characters. '/sites/wolfgangglowacki.com.au/files/print_images/CV011 The Great Ravine.jpg' (found at least ' ')
# [Error]Invalid image, not saving https://photojsureka.files.wordpress.com/2011/08/ravine-3.jpg?w=1280
#
# [!] Issue getting: https://photojsureka.files.wordpress.com/2011/08/ravine-3.jpg?w=1280
# [!] Error:: Invalid image, not saving https://photojsureka.files.wordpress.com/2011/08/ravine-3.jpg?w=1280
#
# [!] Issue getting: https://gameplay.tips/uploads/posts/2019-06/1559760360_3.jpg
# [!] Error:: HTTP Error 503: Service Temporarily Unavailable
# [Error]Invalid image, not saving http://i222.photobucket.com/albums/dd263/Nytewolf2k7/minecraft/2011-08-30_235424.png
#
# [!] Issue getting: http://i222.photobucket.com/albums/dd263/Nytewolf2k7/minecraft/2011-08-30_235424.png
# [!] Error:: Invalid image, not saving http://i222.photobucket.com/albums/dd263/Nytewolf2k7/minecraft/2011-08-30_235424.png
#
#
#
# [%] Done. Downloaded 5 images.
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp/weld
# [Error]Invalid image, not saving http://funphysicist.byethost14.com/oc_subsite/weldingrodeoimg/welding.jpg
#
# [!] Issue getting: http://funphysicist.byethost14.com/oc_subsite/weldingrodeoimg/welding.jpg
# [!] Error:: Invalid image, not saving http://funphysicist.byethost14.com/oc_subsite/weldingrodeoimg/welding.jpg
#
#
#
# [%] Done. Downloaded 5 images.
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp/firkin
#
#
# [%] Done. Downloaded 5 images.
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp/small boat
#
#
# [%] Done. Downloaded 5 images.
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp/wildflower
#
#
# [%] Done. Downloaded 5 images.
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp/lobster newburg
# [!] Issue getting: https://www.familycookbookproject.com/images/userimages/407314recipepix53409.jpg
# [!] Error:: HTTP Error 403: Forbidden
#
#
# [%] Done. Downloaded 5 images.
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp/abrading stone
# [!] Issue getting: http://www.penbrandt.com/penbrandtprehistoricartifacts/images/HS238 (2).jpg
# [!] Error:: URL can't contain control characters. '/penbrandtprehistoricartifacts/images/HS238 (2).jpg' (found at least ' ')
# [Error]Invalid image, not saving https://live.staticflickr.com/3483/3701487769_dd38e710f6_z.jpg
#
# [!] Issue getting: https://live.staticflickr.com/3483/3701487769_dd38e710f6_z.jpg
# [!] Error:: Invalid image, not saving https://live.staticflickr.com/3483/3701487769_dd38e710f6_z.jpg
#
#
#
# [%] Done. Downloaded 5 images.
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp/veronica
#
#
# [%] Done. Downloaded 5 images.
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp/shore pine
# [!] Issue getting: https://www.monrovia.com/media/catalog/product/cache/c9ce50e50c7861597f96888746179a48/r/e/rest_1_1_1116.jpeg
# [!] Error:: HTTP Error 403: Forbidden
#
#
# [%] Done. Downloaded 5 images.
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp/spade bit
# [!] Issue getting: https://www.harborfreight.com/media/catalog/product/6/9/69015_W3.jpg
# [!] Error:: HTTP Error 405: Not allowed
#
#
# [%] Done. Downloaded 5 images.
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp/honeycomb
#
#
# [%] Done. Downloaded 5 images.
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp/settler
#
#
# [%] Done. Downloaded 5 images.
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp/skateboard
#
#
# [%] Done. Downloaded 5 images.
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp/fen orchid
#
#
# [%] Done. Downloaded 5 images.
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp/cushaw
#
#
# [%] Done. Downloaded 5 images.
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp/compress
# [Error]Invalid image, not saving https://compress-online.com/assets/img/compress-jpg.svg
#
# [!] Issue getting: https://compress-online.com/assets/img/compress-jpg.svg
# [!] Error:: Invalid image, not saving https://compress-online.com/assets/img/compress-jpg.svg
#
#
#
# [%] Done. Downloaded 5 images.
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp
#
#
# [%] Done. Downloaded 5 images.
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp/newel
# [!] Issue getting: http://media.stanleyfurniture.com/collections/171/contemporary/newel/collection%20page%20images/newel1.jpg
# [!] Error:: HTTP Error 522:
#
#
# [%] Done. Downloaded 5 images.
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp/black ash
#
#
# [%] Done. Downloaded 5 images.
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp/sweet buckeye
#
#
# [%] Done. Downloaded 5 images.
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp/toothed spurge
# [!] Issue getting: http://lucasland.org/New Images 2016/toothedspurge.jpg
# [!] Error:: URL can't contain control characters. '/New Images 2016/toothedspurge.jpg' (found at least ' ')
#
#
# [%] Done. Downloaded 5 images.
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp/texas snowbell
# [Error]Invalid image, not saving https://endangeredandnotsomuch.files.wordpress.com/2018/12/29-5.jpg?w=1536
#
# [!] Issue getting: https://endangeredandnotsomuch.files.wordpress.com/2018/12/29-5.jpg?w=1536
# [!] Error:: Invalid image, not saving https://endangeredandnotsomuch.files.wordpress.com/2018/12/29-5.jpg?w=1536
#
#
#
# [%] Done. Downloaded 5 images.
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp/earplug
#
#
# [%] Done. Downloaded 5 images.
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp/water filter
#
#
# [%] Done. Downloaded 5 images.
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp/gamp
#
#
# [%] Done. Downloaded 5 images.
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp/flying buttress
# [!] Issue getting: http://england.picturesofus.net/2010/Tewkesbury/Abbey/slides/Flying Buttress.JPG
# [!] Error:: URL can't contain control characters. '/2010/Tewkesbury/Abbey/slides/Flying Buttress.JPG' (found at least ' ')
# [Error]Invalid image, not saving https://live.staticflickr.com/3260/3165868051_0a7e666104_h.jpg
#
# [!] Issue getting: https://live.staticflickr.com/3260/3165868051_0a7e666104_h.jpg
# [!] Error:: Invalid image, not saving https://live.staticflickr.com/3260/3165868051_0a7e666104_h.jpg
#
# [!] Issue getting: https://sp-images.summitpost.org/299810.jpg?auto=format&amp;fit=max&amp;ixlib=php-2.1.1&amp;q=35&amp;w=1024&amp;s=1a0210683cfa987a153cc6a9f464cd9d
# [!] Error:: HTTP Error 403: Forbidden
#
#
# [%] Done. Downloaded 5 images.
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp/medical officer
# [!] Issue getting: https://www.physicianleaders.org/hubfs/PLL_Collateral/201806 June 2018/chief medical officer.jpg
# [!] Error:: URL can't contain control characters. '/hubfs/PLL_Collateral/201806 June 2018/chief medical officer.jpg' (found at least ' ')
# [!] Issue getting: https://staging.navy.com/sites/default/files/video_thumbnails/6Z-Y3S7AMHQ.jpg
# [!] Error:: <urlopen error [Errno 8] nodename nor servname provided, or not known>
# [Error]Invalid image, not saving https://live.staticflickr.com/7398/12000091275_fda9c028aa_b.jpg
#
# [!] Issue getting: https://live.staticflickr.com/7398/12000091275_fda9c028aa_b.jpg
# [!] Error:: Invalid image, not saving https://live.staticflickr.com/7398/12000091275_fda9c028aa_b.jpg
#
#
#
# [%] Done. Downloaded 5 images.
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp/slippery elm
# ...
# [!] Error:: <urlopen error timed out>
#
#
# [%] Done. Downloaded 5 images.
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp/dinner dress
# [Error]Invalid image, not saving http://therewentthebride.files.wordpress.com/2008/06/dress4.jpg
#
# [!] Issue getting: http://therewentthebride.files.wordpress.com/2008/06/dress4.jpg
# [!] Error:: Invalid image, not saving http://therewentthebride.files.wordpress.com/2008/06/dress4.jpg
#
#
#
# [%] Done. Downloaded 5 images.
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp/creme caramel
#
#
# [%] Done. Downloaded 5 images.
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp/taboret
#
#
# [%] Done. Downloaded 5 images.
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp/reaumur thermometer
# [Error]Invalid image, not saving http://users.telenet.be/instrumentatie/images/thermometer-Fahrenheit-Reaumur.jpg
#
# [!] Issue getting: http://users.telenet.be/instrumentatie/images/thermometer-Fahrenheit-Reaumur.jpg
# [!] Error:: Invalid image, not saving http://users.telenet.be/instrumentatie/images/thermometer-Fahrenheit-Reaumur.jpg
#
#
#
# [%] Done. Downloaded 5 images.
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp/stamp mill
#
#
# [%] Done. Downloaded 5 images.
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp/chair of state
# [!] Issue getting: https://assets3.parliament.uk/iv/ig-portrait-large/ImageVault/Images/scope_0/filename_37dBmRDpSLyBibttNEaV.jpg/storage_Edited/ImageVaultHandler.aspx.jpg
# [!] Error:: HTTP Error 403: Forbidden
#
#
# [%] Done. Downloaded 5 images.
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp
#
#
# [%] Done. Downloaded 5 images.
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp/crystal detector
# [!] Issue getting: https://www.picclickimg.com/d/l400/pict/190808452775_/Crystal-Detector.jpg
# [!] Error:: HTTP Error 404: Not Found
# [!] Issue getting: http://www.sparkmuseum.com/images/Wireless/WIRE58.GIF
# [!] Error:: HTTP Error 403: Forbidden
#
#
# [%] Done. Downloaded 5 images.
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp/miniature golf
#
#
# [%] Done. Downloaded 5 images.
# [%] Downloading Images to /Users/jychan/Desktop/birdr/dataset/temp/coltsfoot
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-64-fc8d3569b942> in <module>
#       2 from bing_image_downloader import downloader
#       3 for query in non_bird_name[7050:]:
# ----> 4     downloader.download(query, limit=5,  output_dir='dataset/temp', force_replace=False, verbose=False)
#
# ~/Library/Python/3.8/lib/python/site-packages/bing_image_downloader/downloader.py in download(query, limit, output_dir, adult_filter_off, force_replace, timeout, filter, verbose)
#      36     print("[%] Downloading Images to {}".format(str(image_dir.absolute())))
#      37     bing = Bing(query, limit, image_dir, adult, timeout, filter, verbose)
# ---> 38     bing.run()
#      39
#      40
#
# ~/Library/Python/3.8/lib/python/site-packages/bing_image_downloader/bing.py in run(self)
#     110                 if self.download_count < self.limit and link not in self.seen:
#     111                     self.seen.add(link)
# --> 112                     self.download_image(link)
#     113
#     114             self.page_counter += 1
#
# ~/Library/Python/3.8/lib/python/site-packages/bing_image_downloader/bing.py in download_image(self, link)
#      78                 print("[%] Downloading Image #{} from {}".format(self.download_count, link))
#      79
# ---> 80             self.save_image(link, self.output_dir.joinpath("Image_{}.{}".format(
#      81                 str(self.download_count), file_type)))
#      82             if self.verbose:
#
# ~/Library/Python/3.8/lib/python/site-packages/bing_image_downloader/bing.py in save_image(self, link, file_path)
#      56     def save_image(self, link, file_path):
#      57         request = urllib.request.Request(link, None, self.headers)
# ---> 58         image = urllib.request.urlopen(request, timeout=self.timeout).read()
#      59         if not imghdr.what(None, image):
#      60             print('[Error]Invalid image, not saving {}\n'.format(link))
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/http/client.py in read(self, amt)
#     466             else:
#     467                 try:
# --> 468                     s = self._safe_read(self.length)
#     469                 except IncompleteRead:
#     470                     self._close_conn()
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/http/client.py in _safe_read(self, amt)
#     607         IncompleteRead exception can be used to detect the problem.
#     608         """
# --> 609         data = self.fp.read(amt)
#     610         if len(data) < amt:
#     611             raise IncompleteRead(data, amt-len(data))
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
# Move non-bird image to 0_non_bird directory in train/valid/test directory
# train -7k, valid-2k, test-1k

# Move all images to non_bird_images directory
non_bird_dir = './dataset/non_bird_images'

file_names = os.listdir(non_bird_dir)
name=1
for file_name in file_names:
    for image in os.listdir(os.path.join(non_bird_dir,file_name)):
        new_filename = 'a'+str(name)+'.jpg'
        os.rename(os.path.join(non_bird_dir, file_name,image), os.path.join(non_bird_dir, file_name, new_filename))
        shutil.move(os.path.join(non_bird_dir, file_name,new_filename), non_bird_dir)
        name+=1

# %%
# Training set
source_dir = './dataset/non_bird_images'
target_dir = './dataset/train/0_non_bird'

for image in random.sample(os.listdir(source_dir), 7000):
    shutil.move(os.path.join(source_dir,image), target_dir)

# Validation set
target_dir = './dataset/valid/0_non_bird'
for image in random.sample(os.listdir(source_dir), 2000):
    shutil.move(os.path.join(source_dir,image), target_dir)

# Test set
target_dir = './dataset/test/0_non_bird'
for image in random.sample(os.listdir(source_dir), 1000):
    shutil.move(os.path.join(source_dir,image), target_dir)
